# %%
import numpy as np
import cv2

# %%
#X_64t= np.load("X_64t.npy")
X_64t.shape
X_64t_128s= np.zeros(shape=(890,64,128,128))

# %%
for vid in range(X_64t.shape[0]):
    for frame in range(X_64t.shape[1]):
        X_64t_128s[vid,frame] = cv2.resize(X_64t[vid,frame].squeeze(), (128,128))

# %%
# X_64t_128s_OK= np.expand_dims(X_64t_128s, axis=-1)

# np.save("X_64t_128s_OK.npy", X_64t_128s_OK)
# X_64t_128s_OK.shape
# Out:
# (890, 64, 128, 128, 1)
